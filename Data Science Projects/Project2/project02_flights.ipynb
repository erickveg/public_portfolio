# %% [markdown]
# # Project 2: Are we missing JSON on our flight?

# %%
import pandas as pd   # to load and transform data
import numpy as np    # for math/stat calculations
import altair as alt

# from file to pandas dataframe
flights = pd.read_json("flights_missing.json")

# %% [markdown]
# ## 1. Which airport has the worst delays?

# %%
prop_total_delays = (flights.groupby('airport_code')
    .agg(total_flights = ('num_of_flights_total', sum),
        total_delays = ('num_of_delays_total', sum),
        total_delay_mins = ('minutes_delayed_total', sum))
    .assign(prop_delays = lambda x: x.total_delays / x.total_flights,
            avg_delay_hours = lambda x: x.total_delay_mins / x.total_delays / 60)
    .sort_values(by = ["prop_delays", "avg_delay_hours"], ascending = False)
)

print(prop_total_delays.to_markdown(floatfmt='.2f'))
# Out:
# | airport_code   |   total_flights |   total_delays |   total_delay_mins |   prop_delays |   avg_delay_hours |
# |:---------------|----------------:|---------------:|-------------------:|--------------:|------------------:|
# | SFO            |      1630945.00 |      425604.00 |        26550493.00 |          0.26 |              1.04 |
# | ORD            |      3597588.00 |      830825.00 |        56356129.00 |          0.23 |              1.13 |
# | ATL            |      4430047.00 |      902443.00 |        53983926.00 |          0.20 |              1.00 |
# | IAD            |       851571.00 |      168467.00 |        10283478.00 |          0.20 |              1.02 |
# | SAN            |       917862.00 |      175132.00 |         8276248.00 |          0.19 |              0.79 |
# | DEN            |      2513974.00 |      468519.00 |        25173381.00 |          0.19 |              0.90 |
# | SLC            |      1403384.00 |      205160.00 |        10123371.00 |          0.15 |              0.82 |

# %% [markdown]
# ## 2. What is the best month to fly if you want to avoid delays of any length?

# %%
# Create a new DataFrame without those rows that contains "n/a" under the column 'month'
clear_months = (flights.drop(flights.index[flights["month"] == "n/a"]))

# Create a DataFrame where the rows are grouped by airport_code and month
delays_airport_month = (clear_months.groupby(by=["airport_code", "month"])
        .agg(total_delays_per_month = ("num_of_delays_total",sum))
        .reset_index()
        )

# Create a chart representing how many delays have had each airport for each month
base_chart = (alt.Chart(delays_airport_month)
             .encode(
                x = alt.X("month",
                        title = "Month",
                        sort=["January", "Febuary", "March", "April", "May", "June",
                                    "July", "August", "September", "October", "November", "December"]),
                y = alt.Y("total_delays_per_month",
                        title = "Total of Delays per Airport"),

                color = "airport_code"
            )
            .mark_line()
            .configure_axis(
                    grid=True)
        .properties(title = "Most airports report an increase of delays on June and July"))

base_chart
# Out:
# alt.Chart(...)

# %%
delays_month_proportion = (clear_months.groupby('month')
    .agg(total_flights = ('num_of_flights_total', sum),
        total_delays = ('num_of_delays_total', sum))
    .assign(prop_delays = lambda x: x.total_delays / x.total_flights *100)
    .reset_index()
)

base_chart2 = (alt.Chart(delays_month_proportion)
                .encode(
                    x = alt.X("month",
                            title = "Month",
                            sort=["January", "Febuary", "March", "April", "May", "June",
                                    "July", "August", "September", "October", "November", "December"]),
                    y = alt.Y("prop_delays",
                            title="Total proportion of delays (%)",
                            scale=alt.Scale(zero=False)))                   
                .mark_bar()
                .configure_axis(
                    grid=True)
                .properties(title = """In proportion, December is the month with most delayed flights"""))

base_chart2
# Out:
# alt.Chart(...)

# %% [markdown]
# ## 3. Create a new column that calculates the total number of flights delayed by weather (both severe and mild).

# %%
# Calculate the average of the column um_of_Delays_late_aircraft
late_aircraft_avg = flights.num_of_delays_late_aircraft.replace(-999,np.nan).mean()

# Copy the orifinal DataFrame
q3 = flights

# Replace all the invalid values -999 with a standard missing value only in the column "num_of_delays_late_aircraft"
q3.num_of_delays_late_aircraft.replace(-999, late_aircraft_avg, inplace = True)

# Calculate how many flights were delayed because of severe and mild weather conditions
weather = q3.assign(
    severe_weather = q3.num_of_delays_weather,
    mild_weather_late_aircraft = .3*q3.num_of_delays_late_aircraft,
    mild_weather_nas = np.where(q3.month.isin(["April","May","June","July","August"]), 
                                    .4*q3.num_of_delays_nas, 
                                    .65*q3.num_of_delays_nas),
    num_delays_weather =  lambda x: x.severe_weather + x.mild_weather_late_aircraft + x.mild_weather_nas

)

print(weather[["airport_code","severe_weather","mild_weather_late_aircraft","mild_weather_nas","num_delays_weather"]].head().to_markdown())
# Out:
# |    | airport_code   |   severe_weather |   mild_weather_late_aircraft |   mild_weather_nas |   num_delays_weather |
# |---:|:---------------|-----------------:|-----------------------------:|-------------------:|---------------------:|
# |  0 | ATL            |              448 |                      332.731 |            2988.7  |              3769.43 |
# |  1 | DEN            |              233 |                      278.4   |             607.75 |              1119.15 |
# |  2 | IAD            |               61 |                      317.4   |             581.75 |               960.15 |
# |  3 | ORD            |              306 |                      676.5   |            3519.75 |              4502.25 |
# |  4 | SAN            |               56 |                      204     |             414.7  |               674.7  |

# %% [markdown]
# ## 4. Create a barplot showing the proportion of all flights that are delayed by weather at each airport.

# %%
# Create a DataFrame that contains the proportion of delays caused by weather conditions grouped by airport
delays_by_weather_by_airport = (weather.groupby('airport_code')
    .agg(total_flights = ('num_of_flights_total'),
        total_delays_weather = ('num_delays_weather', sum))
    .assign(prop_delays_weather = lambda x: x.total_delays_weather / x.total_flights *100 )
    .reset_index()
    
)


delays_by_weather_by_airport
# Out:
#   airport_code  total_flights  total_delays_weather  prop_delays_weather
# 0          ATL        4430047         314800.623982             7.106034
# 1          DEN        2513974         149106.950000             5.931125
# 2          IAD         851571          50842.650000             5.970453
# 3          ORD        3597588         309954.074887             8.615608
# 4          SAN         917862          48920.550000             5.329837
# 5          SFO        1630945         159593.700000             9.785351
# 6          SLC        1403384          60345.750000             4.300017

# %%
base_chart3 = (alt.Chart(delays_by_weather_by_airport)
                    .encode(
                        x = alt.X("airport_code",
                        title="Airport Code"),
                        y = alt.Y("prop_delays_weather",
                        title="Proportion of delays by weather(%)"),
                        color = "airport_code"
                    )
                    .mark_bar()
                    .properties(title="Less than 10% of all the delayed flights were caused by weather conditions")
)

base_chart3
# Out:
# alt.Chart(...)

# %% [markdown]
# ## 5. Fix all of the varied missing data types in the data to be consistent

# %%
import json

# Replace all the missing values with NaN
consistent_flights = flights.replace([-999,"1500+","","n/a"], np.nan)
consistent_flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 924 entries, 0 to 923
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   airport_code                   924 non-null    object
#  1   airport_name                   868 non-null    object
#  2   month                          897 non-null    object
#  3   year                           901 non-null    float64
#  4   num_of_flights_total           924 non-null    int64
#  5   num_of_delays_carrier          851 non-null    object
#  6   num_of_delays_late_aircraft    924 non-null    float64
#  7   num_of_delays_nas              924 non-null    int64
#  8   num_of_delays_security         924 non-null    int64
#  9   num_of_delays_weather          924 non-null    int64
#  10  num_of_delays_total            924 non-null    int64
#  11  minutes_delayed_carrier        872 non-null    float64
#  12  minutes_delayed_late_aircraft  924 non-null    int64
#  13  minutes_delayed_nas            876 non-null    float64
#  14  minutes_delayed_security       924 non-null    int64
#  15  minutes_delayed_weather        924 non-null    int64
#  16  minutes_delayed_total          924 non-null    int64
# dtypes: float64(4), int64(9), object(4)
# memory usage: 122.8+ KB

# %%
# Create a DataFrame with only those rows that contain NaN values
nan_flights= consistent_flights[consistent_flights.isna().any(axis=1)]

# Using the DataFrame created above, create a json document
json_flights = nan_flights.to_json(orient="records")
json_object = json.loads(json_flights)
json_formatted_str = json.dumps(json_object, indent = 4)
print(json_formatted_str)
# Out:
# [
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "January",
#         "year": 2005.0,
#         "num_of_flights_total": 35048,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 4598,
#         "num_of_delays_security": 10,
#         "num_of_delays_weather": 448,
#         "num_of_delays_total": 8355,
#         "minutes_delayed_carrier": 116423.0,
#         "minutes_delayed_late_aircraft": 104415,
#         "minutes_delayed_nas": 207467.0,
#         "minutes_delayed_security": 297,
#         "minutes_delayed_weather": 36931,
#         "minutes_delayed_total": 465533
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": null,
#         "month": "January",
#         "year": 2005.0,
#         "num_of_flights_total": 12381,
#         "num_of_delays_carrier": "414",
#         "num_of_delays_late_aircraft": 1058.0,
#         "num_of_delays_nas": 895,
#         "num_of_delays_security": 4,
#         "num_of_delays_weather": 61,
#         "num_of_delays_total": 2430,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 70919,
#         "minutes_delayed_nas": 35660.0,
#         "minutes_delayed_security": 208,
#         "minutes_delayed_weather": 4497,
#         "minutes_delayed_total": 134881
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "Febuary",
#         "year": 2005.0,
#         "num_of_flights_total": 10042,
#         "num_of_delays_carrier": "284",
#         "num_of_delays_late_aircraft": 631.0,
#         "num_of_delays_nas": 691,
#         "num_of_delays_security": 4,
#         "num_of_delays_weather": 28,
#         "num_of_delays_total": 1639,
#         "minutes_delayed_carrier": 15573.0,
#         "minutes_delayed_late_aircraft": 39840,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 169,
#         "minutes_delayed_weather": 1359,
#         "minutes_delayed_total": 78878
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "Febuary",
#         "year": 2005.0,
#         "num_of_flights_total": 9327,
#         "num_of_delays_carrier": "599",
#         "num_of_delays_late_aircraft": 457.0,
#         "num_of_delays_nas": 1010,
#         "num_of_delays_security": 0,
#         "num_of_delays_weather": 57,
#         "num_of_delays_total": 2122,
#         "minutes_delayed_carrier": 30760.0,
#         "minutes_delayed_late_aircraft": 27302,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 6,
#         "minutes_delayed_weather": 3178,
#         "minutes_delayed_total": 110995
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": null,
#         "month": "Febuary",
#         "year": 2005.0,
#         "num_of_flights_total": 12404,
#         "num_of_delays_carrier": "645",
#         "num_of_delays_late_aircraft": 463.0,
#         "num_of_delays_nas": 752,
#         "num_of_delays_security": 10,
#         "num_of_delays_weather": 79,
#         "num_of_delays_total": 1947,
#         "minutes_delayed_carrier": 32336.0,
#         "minutes_delayed_late_aircraft": 23087,
#         "minutes_delayed_nas": 24544.0,
#         "minutes_delayed_security": 293,
#         "minutes_delayed_weather": 4614,
#         "minutes_delayed_total": 84874
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "March",
#         "year": 2005.0,
#         "num_of_flights_total": 37806,
#         "num_of_delays_carrier": "1462",
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 5697,
#         "num_of_delays_security": 11,
#         "num_of_delays_weather": 423,
#         "num_of_delays_total": 9431,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 150766,
#         "minutes_delayed_nas": 396191.0,
#         "minutes_delayed_security": 568,
#         "minutes_delayed_weather": 33379,
#         "minutes_delayed_total": 691887
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "April",
#         "year": null,
#         "num_of_flights_total": 36881,
#         "num_of_delays_carrier": "1283",
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 2734,
#         "num_of_delays_security": 6,
#         "num_of_delays_weather": 316,
#         "num_of_delays_total": 5748,
#         "minutes_delayed_carrier": 87994.0,
#         "minutes_delayed_late_aircraft": 104417,
#         "minutes_delayed_nas": 173772.0,
#         "minutes_delayed_security": 295,
#         "minutes_delayed_weather": 30566,
#         "minutes_delayed_total": 397044
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "April",
#         "year": 2005.0,
#         "num_of_flights_total": 27634,
#         "num_of_delays_carrier": "811",
#         "num_of_delays_late_aircraft": 980.0,
#         "num_of_delays_nas": 1900,
#         "num_of_delays_security": 5,
#         "num_of_delays_weather": 93,
#         "num_of_delays_total": 3786,
#         "minutes_delayed_carrier": 50443.0,
#         "minutes_delayed_late_aircraft": 53496,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 186,
#         "minutes_delayed_weather": 5791,
#         "minutes_delayed_total": 188222
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": null,
#         "month": "April",
#         "year": 2005.0,
#         "num_of_flights_total": 7091,
#         "num_of_delays_carrier": "364",
#         "num_of_delays_late_aircraft": 369.0,
#         "num_of_delays_nas": 343,
#         "num_of_delays_security": 2,
#         "num_of_delays_weather": 15,
#         "num_of_delays_total": 1095,
#         "minutes_delayed_carrier": 15602.0,
#         "minutes_delayed_late_aircraft": 15994,
#         "minutes_delayed_nas": 10015.0,
#         "minutes_delayed_security": 59,
#         "minutes_delayed_weather": 792,
#         "minutes_delayed_total": 42462
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "June",
#         "year": 2005.0,
#         "num_of_flights_total": 37209,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 6892,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 479,
#         "num_of_delays_total": 10986,
#         "minutes_delayed_carrier": 119455.0,
#         "minutes_delayed_late_aircraft": 134768,
#         "minutes_delayed_nas": 343189.0,
#         "minutes_delayed_security": 390,
#         "minutes_delayed_weather": 32914,
#         "minutes_delayed_total": 630716
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": null,
#         "month": "June",
#         "year": 2005.0,
#         "num_of_flights_total": 13860,
#         "num_of_delays_carrier": "788",
#         "num_of_delays_late_aircraft": 642.0,
#         "num_of_delays_nas": 670,
#         "num_of_delays_security": 7,
#         "num_of_delays_weather": 95,
#         "num_of_delays_total": 2203,
#         "minutes_delayed_carrier": 37008.0,
#         "minutes_delayed_late_aircraft": 31149,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 162,
#         "minutes_delayed_weather": 5223,
#         "minutes_delayed_total": 98063
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "July",
#         "year": null,
#         "num_of_flights_total": 37584,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 8704,
#         "num_of_delays_security": 14,
#         "num_of_delays_weather": 466,
#         "num_of_delays_total": 13699,
#         "minutes_delayed_carrier": 156293.0,
#         "minutes_delayed_late_aircraft": 219063,
#         "minutes_delayed_nas": 574857.0,
#         "minutes_delayed_security": 678,
#         "minutes_delayed_weather": 38476,
#         "minutes_delayed_total": 989367
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "July",
#         "year": 2005.0,
#         "num_of_flights_total": 28283,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 2241.0,
#         "num_of_delays_nas": 3547,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 213,
#         "num_of_delays_total": 7641,
#         "minutes_delayed_carrier": 121159.0,
#         "minutes_delayed_late_aircraft": 181764,
#         "minutes_delayed_nas": 237346.0,
#         "minutes_delayed_security": 443,
#         "minutes_delayed_weather": 17190,
#         "minutes_delayed_total": 557902
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "August",
#         "year": 2005.0,
#         "num_of_flights_total": 37886,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 8440,
#         "num_of_delays_security": 11,
#         "num_of_delays_weather": 381,
#         "num_of_delays_total": 12861,
#         "minutes_delayed_carrier": 140274.0,
#         "minutes_delayed_late_aircraft": 154147,
#         "minutes_delayed_nas": 487160.0,
#         "minutes_delayed_security": 459,
#         "minutes_delayed_weather": 28593,
#         "minutes_delayed_total": 810633
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "September",
#         "year": 2005.0,
#         "num_of_flights_total": 7451,
#         "num_of_delays_carrier": "414",
#         "num_of_delays_late_aircraft": 419.0,
#         "num_of_delays_nas": 420,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 31,
#         "num_of_delays_total": 1286,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 17110,
#         "minutes_delayed_nas": 12249.0,
#         "minutes_delayed_security": 119,
#         "minutes_delayed_weather": 1607,
#         "minutes_delayed_total": 47963
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "November",
#         "year": 2005.0,
#         "num_of_flights_total": 12970,
#         "num_of_delays_carrier": "650",
#         "num_of_delays_late_aircraft": 469.0,
#         "num_of_delays_nas": 735,
#         "num_of_delays_security": 10,
#         "num_of_delays_weather": 83,
#         "num_of_delays_total": 1947,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 21458,
#         "minutes_delayed_nas": 21904.0,
#         "minutes_delayed_security": 305,
#         "minutes_delayed_weather": 3855,
#         "minutes_delayed_total": 75354
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "December",
#         "year": 2005.0,
#         "num_of_flights_total": 33632,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 4898,
#         "num_of_delays_security": 12,
#         "num_of_delays_weather": 509,
#         "num_of_delays_total": 9899,
#         "minutes_delayed_carrier": 130387.0,
#         "minutes_delayed_late_aircraft": 139313,
#         "minutes_delayed_nas": 255257.0,
#         "minutes_delayed_security": 479,
#         "minutes_delayed_weather": 33154,
#         "minutes_delayed_total": 558590
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "December",
#         "year": 2005.0,
#         "num_of_flights_total": 16404,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1183.0,
#         "num_of_delays_nas": 1333,
#         "num_of_delays_security": 11,
#         "num_of_delays_weather": 145,
#         "num_of_delays_total": 4293,
#         "minutes_delayed_carrier": 79791.0,
#         "minutes_delayed_late_aircraft": 73731,
#         "minutes_delayed_nas": 43131.0,
#         "minutes_delayed_security": 249,
#         "minutes_delayed_weather": 9461,
#         "minutes_delayed_total": 206363
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "December",
#         "year": 2005.0,
#         "num_of_flights_total": 7494,
#         "num_of_delays_carrier": "408",
#         "num_of_delays_late_aircraft": 550.0,
#         "num_of_delays_nas": 471,
#         "num_of_delays_security": 1,
#         "num_of_delays_weather": 36,
#         "num_of_delays_total": 1466,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 32991,
#         "minutes_delayed_nas": 14510.0,
#         "minutes_delayed_security": 120,
#         "minutes_delayed_weather": 2706,
#         "minutes_delayed_total": 72899
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "December",
#         "year": 2005.0,
#         "num_of_flights_total": 29229,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 2586.0,
#         "num_of_delays_nas": 4713,
#         "num_of_delays_security": 17,
#         "num_of_delays_weather": 292,
#         "num_of_delays_total": 9479,
#         "minutes_delayed_carrier": 114235.0,
#         "minutes_delayed_late_aircraft": 168738,
#         "minutes_delayed_nas": 303125.0,
#         "minutes_delayed_security": 674,
#         "minutes_delayed_weather": 22736,
#         "minutes_delayed_total": 609512
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "January",
#         "year": 2006.0,
#         "num_of_flights_total": 33274,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1506.0,
#         "num_of_delays_nas": 4563,
#         "num_of_delays_security": 7,
#         "num_of_delays_weather": 401,
#         "num_of_delays_total": 8109,
#         "minutes_delayed_carrier": 116197.0,
#         "minutes_delayed_late_aircraft": 122615,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 203,
#         "minutes_delayed_weather": 32153,
#         "minutes_delayed_total": 548821
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "January",
#         "year": 2006.0,
#         "num_of_flights_total": 30828,
#         "num_of_delays_carrier": "1308",
#         "num_of_delays_late_aircraft": 1849.0,
#         "num_of_delays_nas": 3820,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 188,
#         "num_of_delays_total": 7177,
#         "minutes_delayed_carrier": 80222.0,
#         "minutes_delayed_late_aircraft": 133127,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 309,
#         "minutes_delayed_weather": 15707,
#         "minutes_delayed_total": 441216
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "Febuary",
#         "year": 2006.0,
#         "num_of_flights_total": 9742,
#         "num_of_delays_carrier": "757",
#         "num_of_delays_late_aircraft": 645.0,
#         "num_of_delays_nas": 1573,
#         "num_of_delays_security": 4,
#         "num_of_delays_weather": 66,
#         "num_of_delays_total": 3048,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 40924,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 191,
#         "minutes_delayed_weather": 4435,
#         "minutes_delayed_total": 161355
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "March",
#         "year": 2006.0,
#         "num_of_flights_total": 34988,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1596.0,
#         "num_of_delays_nas": 4458,
#         "num_of_delays_security": 13,
#         "num_of_delays_weather": 286,
#         "num_of_delays_total": 7870,
#         "minutes_delayed_carrier": 92476.0,
#         "minutes_delayed_late_aircraft": 82823,
#         "minutes_delayed_nas": 194182.0,
#         "minutes_delayed_security": 1024,
#         "minutes_delayed_weather": 15803,
#         "minutes_delayed_total": 386308
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "April",
#         "year": 2006.0,
#         "num_of_flights_total": 33251,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 3775,
#         "num_of_delays_security": 39,
#         "num_of_delays_weather": 317,
#         "num_of_delays_total": 7104,
#         "minutes_delayed_carrier": 99162.0,
#         "minutes_delayed_late_aircraft": 84534,
#         "minutes_delayed_nas": 172490.0,
#         "minutes_delayed_security": 4949,
#         "minutes_delayed_weather": 19977,
#         "minutes_delayed_total": 381112
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "April",
#         "year": 2006.0,
#         "num_of_flights_total": 18308,
#         "num_of_delays_carrier": "917",
#         "num_of_delays_late_aircraft": 992.0,
#         "num_of_delays_nas": 773,
#         "num_of_delays_security": 11,
#         "num_of_delays_weather": 49,
#         "num_of_delays_total": 2744,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 54348,
#         "minutes_delayed_nas": 24260.0,
#         "minutes_delayed_security": 585,
#         "minutes_delayed_weather": 2937,
#         "minutes_delayed_total": 129465
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "May",
#         "year": 2006.0,
#         "num_of_flights_total": 34291,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 3988,
#         "num_of_delays_security": 8,
#         "num_of_delays_weather": 341,
#         "num_of_delays_total": 7534,
#         "minutes_delayed_carrier": 96728.0,
#         "minutes_delayed_late_aircraft": 91200,
#         "minutes_delayed_nas": 169093.0,
#         "minutes_delayed_security": 271,
#         "minutes_delayed_weather": 18692,
#         "minutes_delayed_total": 375984
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "June",
#         "year": 2006.0,
#         "num_of_flights_total": 33787,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 2276.0,
#         "num_of_delays_nas": 3086,
#         "num_of_delays_security": 8,
#         "num_of_delays_weather": 638,
#         "num_of_delays_total": 8470,
#         "minutes_delayed_carrier": 166260.0,
#         "minutes_delayed_late_aircraft": 160781,
#         "minutes_delayed_nas": 184943.0,
#         "minutes_delayed_security": 512,
#         "minutes_delayed_weather": 46773,
#         "minutes_delayed_total": 559269
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "June",
#         "year": 2006.0,
#         "num_of_flights_total": 7838,
#         "num_of_delays_carrier": "623",
#         "num_of_delays_late_aircraft": 903.0,
#         "num_of_delays_nas": 604,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 54,
#         "num_of_delays_total": 2188,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 91872,
#         "minutes_delayed_nas": 33278.0,
#         "minutes_delayed_security": 141,
#         "minutes_delayed_weather": 4900,
#         "minutes_delayed_total": 176243
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "June",
#         "year": 2006.0,
#         "num_of_flights_total": 31286,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 3219.0,
#         "num_of_delays_nas": 2927,
#         "num_of_delays_security": 12,
#         "num_of_delays_weather": 216,
#         "num_of_delays_total": 8121,
#         "minutes_delayed_carrier": 116084.0,
#         "minutes_delayed_late_aircraft": 229989,
#         "minutes_delayed_nas": 165308.0,
#         "minutes_delayed_security": 393,
#         "minutes_delayed_weather": 18670,
#         "minutes_delayed_total": 530444
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "June",
#         "year": 2006.0,
#         "num_of_flights_total": 12155,
#         "num_of_delays_carrier": "744",
#         "num_of_delays_late_aircraft": 683.0,
#         "num_of_delays_nas": 412,
#         "num_of_delays_security": 11,
#         "num_of_delays_weather": 78,
#         "num_of_delays_total": 1926,
#         "minutes_delayed_carrier": 35395.0,
#         "minutes_delayed_late_aircraft": 34642,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 297,
#         "minutes_delayed_weather": 5002,
#         "minutes_delayed_total": 89041
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "July",
#         "year": 2006.0,
#         "num_of_flights_total": 35419,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 2757,
#         "num_of_delays_security": 6,
#         "num_of_delays_weather": 539,
#         "num_of_delays_total": 8836,
#         "minutes_delayed_carrier": 180568.0,
#         "minutes_delayed_late_aircraft": 153962,
#         "minutes_delayed_nas": 117474.0,
#         "minutes_delayed_security": 385,
#         "minutes_delayed_weather": 33402,
#         "minutes_delayed_total": 485791
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "July",
#         "year": 2006.0,
#         "num_of_flights_total": 8018,
#         "num_of_delays_carrier": "690",
#         "num_of_delays_late_aircraft": 957.0,
#         "num_of_delays_nas": 577,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 64,
#         "num_of_delays_total": 2292,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 85806,
#         "minutes_delayed_nas": 27743.0,
#         "minutes_delayed_security": 95,
#         "minutes_delayed_weather": 5981,
#         "minutes_delayed_total": 167129
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "July",
#         "year": 2006.0,
#         "num_of_flights_total": 31890,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 3136.0,
#         "num_of_delays_nas": 3339,
#         "num_of_delays_security": 6,
#         "num_of_delays_weather": 235,
#         "num_of_delays_total": 8457,
#         "minutes_delayed_carrier": 123105.0,
#         "minutes_delayed_late_aircraft": 233264,
#         "minutes_delayed_nas": 239564.0,
#         "minutes_delayed_security": 236,
#         "minutes_delayed_weather": 21497,
#         "minutes_delayed_total": 617666
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "August",
#         "year": null,
#         "num_of_flights_total": 35276,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 4152,
#         "num_of_delays_security": 37,
#         "num_of_delays_weather": 562,
#         "num_of_delays_total": 9726,
#         "minutes_delayed_carrier": 179119.0,
#         "minutes_delayed_late_aircraft": 155909,
#         "minutes_delayed_nas": 206507.0,
#         "minutes_delayed_security": 1574,
#         "minutes_delayed_weather": 44144,
#         "minutes_delayed_total": 587253
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "August",
#         "year": 2006.0,
#         "num_of_flights_total": 21498,
#         "num_of_delays_carrier": "1209",
#         "num_of_delays_late_aircraft": 1343.0,
#         "num_of_delays_nas": 976,
#         "num_of_delays_security": 21,
#         "num_of_delays_weather": 161,
#         "num_of_delays_total": 3708,
#         "minutes_delayed_carrier": 63197.0,
#         "minutes_delayed_late_aircraft": 83503,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 801,
#         "minutes_delayed_weather": 9737,
#         "minutes_delayed_total": 193388
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "September",
#         "year": 2006.0,
#         "num_of_flights_total": 32927,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 6941,
#         "num_of_delays_security": 6,
#         "num_of_delays_weather": 509,
#         "num_of_delays_total": 11991,
#         "minutes_delayed_carrier": 154136.0,
#         "minutes_delayed_late_aircraft": 152640,
#         "minutes_delayed_nas": 376714.0,
#         "minutes_delayed_security": 176,
#         "minutes_delayed_weather": 37579,
#         "minutes_delayed_total": 721245
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": null,
#         "year": 2006.0,
#         "num_of_flights_total": 7744,
#         "num_of_delays_carrier": "503",
#         "num_of_delays_late_aircraft": 719.0,
#         "num_of_delays_nas": 384,
#         "num_of_delays_security": 4,
#         "num_of_delays_weather": 32,
#         "num_of_delays_total": 1640,
#         "minutes_delayed_carrier": 33736.0,
#         "minutes_delayed_late_aircraft": 53541,
#         "minutes_delayed_nas": 15447.0,
#         "minutes_delayed_security": 396,
#         "minutes_delayed_weather": 2503,
#         "minutes_delayed_total": 105623
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "September",
#         "year": 2006.0,
#         "num_of_flights_total": 7593,
#         "num_of_delays_carrier": "445",
#         "num_of_delays_late_aircraft": 462.0,
#         "num_of_delays_nas": 441,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 35,
#         "num_of_delays_total": 1391,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 21505,
#         "minutes_delayed_nas": 14806.0,
#         "minutes_delayed_security": 211,
#         "minutes_delayed_weather": 2814,
#         "minutes_delayed_total": 57774
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "October",
#         "year": 2006.0,
#         "num_of_flights_total": 34692,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 7054,
#         "num_of_delays_security": 13,
#         "num_of_delays_weather": 510,
#         "num_of_delays_total": 13124,
#         "minutes_delayed_carrier": 159670.0,
#         "minutes_delayed_late_aircraft": 193311,
#         "minutes_delayed_nas": 353883.0,
#         "minutes_delayed_security": 398,
#         "minutes_delayed_weather": 36968,
#         "minutes_delayed_total": 744230
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "October",
#         "year": 2006.0,
#         "num_of_flights_total": 32244,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 2824.0,
#         "num_of_delays_nas": 5877,
#         "num_of_delays_security": 18,
#         "num_of_delays_weather": 165,
#         "num_of_delays_total": 10412,
#         "minutes_delayed_carrier": 107227.0,
#         "minutes_delayed_late_aircraft": 226658,
#         "minutes_delayed_nas": 465268.0,
#         "minutes_delayed_security": 538,
#         "minutes_delayed_weather": 16628,
#         "minutes_delayed_total": 816319
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "November",
#         "year": 2006.0,
#         "num_of_flights_total": 33691,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 3702,
#         "num_of_delays_security": 6,
#         "num_of_delays_weather": 325,
#         "num_of_delays_total": 8290,
#         "minutes_delayed_carrier": 121134.0,
#         "minutes_delayed_late_aircraft": 115429,
#         "minutes_delayed_nas": 138354.0,
#         "minutes_delayed_security": 238,
#         "minutes_delayed_weather": 22841,
#         "minutes_delayed_total": 397996
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "November",
#         "year": 2006.0,
#         "num_of_flights_total": 18580,
#         "num_of_delays_carrier": "975",
#         "num_of_delays_late_aircraft": 1018.0,
#         "num_of_delays_nas": 770,
#         "num_of_delays_security": 12,
#         "num_of_delays_weather": 91,
#         "num_of_delays_total": 2866,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 59818,
#         "minutes_delayed_nas": 26095.0,
#         "minutes_delayed_security": 633,
#         "minutes_delayed_weather": 7496,
#         "minutes_delayed_total": 141512
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "November",
#         "year": 2006.0,
#         "num_of_flights_total": 8621,
#         "num_of_delays_carrier": "571",
#         "num_of_delays_late_aircraft": 688.0,
#         "num_of_delays_nas": 758,
#         "num_of_delays_security": 5,
#         "num_of_delays_weather": 46,
#         "num_of_delays_total": 2069,
#         "minutes_delayed_carrier": 32001.0,
#         "minutes_delayed_late_aircraft": 48297,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 102,
#         "minutes_delayed_weather": 3385,
#         "minutes_delayed_total": 109253
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "November",
#         "year": 2006.0,
#         "num_of_flights_total": 30537,
#         "num_of_delays_carrier": "1127",
#         "num_of_delays_late_aircraft": 2139.0,
#         "num_of_delays_nas": 4123,
#         "num_of_delays_security": 7,
#         "num_of_delays_weather": 141,
#         "num_of_delays_total": 7536,
#         "minutes_delayed_carrier": 77030.0,
#         "minutes_delayed_late_aircraft": 138172,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 134,
#         "minutes_delayed_weather": 12738,
#         "minutes_delayed_total": 489666
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "December",
#         "year": 2006.0,
#         "num_of_flights_total": 32795,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 2130.0,
#         "num_of_delays_nas": 2243,
#         "num_of_delays_security": 12,
#         "num_of_delays_weather": 262,
#         "num_of_delays_total": 6606,
#         "minutes_delayed_carrier": 127164.0,
#         "minutes_delayed_late_aircraft": 114361,
#         "minutes_delayed_nas": 84763.0,
#         "minutes_delayed_security": 499,
#         "minutes_delayed_weather": 19589,
#         "minutes_delayed_total": 346376
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "December",
#         "year": 2006.0,
#         "num_of_flights_total": 19599,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1590.0,
#         "num_of_delays_nas": 1325,
#         "num_of_delays_security": 20,
#         "num_of_delays_weather": 207,
#         "num_of_delays_total": 4774,
#         "minutes_delayed_carrier": 83727.0,
#         "minutes_delayed_late_aircraft": 103394,
#         "minutes_delayed_nas": 62785.0,
#         "minutes_delayed_security": 854,
#         "minutes_delayed_weather": 21089,
#         "minutes_delayed_total": 271849
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "December",
#         "year": 2006.0,
#         "num_of_flights_total": 31399,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 3277.0,
#         "num_of_delays_nas": 6553,
#         "num_of_delays_security": 19,
#         "num_of_delays_weather": 215,
#         "num_of_delays_total": 11592,
#         "minutes_delayed_carrier": 100134.0,
#         "minutes_delayed_late_aircraft": 249757,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 1036,
#         "minutes_delayed_weather": 18903,
#         "minutes_delayed_total": 859189
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "January",
#         "year": 2007.0,
#         "num_of_flights_total": 32266,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 2644,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 414,
#         "num_of_delays_total": 6653,
#         "minutes_delayed_carrier": 120088.0,
#         "minutes_delayed_late_aircraft": 103874,
#         "minutes_delayed_nas": 118084.0,
#         "minutes_delayed_security": 675,
#         "minutes_delayed_weather": 33013,
#         "minutes_delayed_total": 375734
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "January",
#         "year": 2007.0,
#         "num_of_flights_total": 20057,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1983.0,
#         "num_of_delays_nas": 1787,
#         "num_of_delays_security": 11,
#         "num_of_delays_weather": 169,
#         "num_of_delays_total": 5790,
#         "minutes_delayed_carrier": 95689.0,
#         "minutes_delayed_late_aircraft": 125756,
#         "minutes_delayed_nas": 67892.0,
#         "minutes_delayed_security": 482,
#         "minutes_delayed_weather": 13124,
#         "minutes_delayed_total": 302943
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": null,
#         "month": "January",
#         "year": 2007.0,
#         "num_of_flights_total": 8572,
#         "num_of_delays_carrier": "530",
#         "num_of_delays_late_aircraft": 778.0,
#         "num_of_delays_nas": 458,
#         "num_of_delays_security": 2,
#         "num_of_delays_weather": 51,
#         "num_of_delays_total": 1822,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 51350,
#         "minutes_delayed_nas": 16439.0,
#         "minutes_delayed_security": 47,
#         "minutes_delayed_weather": 2902,
#         "minutes_delayed_total": 99051
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "January",
#         "year": 2007.0,
#         "num_of_flights_total": 31839,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 3248.0,
#         "num_of_delays_nas": 5442,
#         "num_of_delays_security": 6,
#         "num_of_delays_weather": 257,
#         "num_of_delays_total": 10628,
#         "minutes_delayed_carrier": 105214.0,
#         "minutes_delayed_late_aircraft": 243469,
#         "minutes_delayed_nas": 370915.0,
#         "minutes_delayed_security": 376,
#         "minutes_delayed_weather": 17429,
#         "minutes_delayed_total": 737403
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "Febuary",
#         "year": 2007.0,
#         "num_of_flights_total": 29766,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 2201,
#         "num_of_delays_security": 10,
#         "num_of_delays_weather": 491,
#         "num_of_delays_total": 6802,
#         "minutes_delayed_carrier": 141872.0,
#         "minutes_delayed_late_aircraft": 115372,
#         "minutes_delayed_nas": 80718.0,
#         "minutes_delayed_security": 361,
#         "minutes_delayed_weather": 35379,
#         "minutes_delayed_total": 373702
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "Febuary",
#         "year": 2007.0,
#         "num_of_flights_total": 18321,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1870.0,
#         "num_of_delays_nas": 1451,
#         "num_of_delays_security": 14,
#         "num_of_delays_weather": 286,
#         "num_of_delays_total": 5241,
#         "minutes_delayed_carrier": 81386.0,
#         "minutes_delayed_late_aircraft": 115840,
#         "minutes_delayed_nas": 51460.0,
#         "minutes_delayed_security": 499,
#         "minutes_delayed_weather": 33341,
#         "minutes_delayed_total": 282526
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "Febuary",
#         "year": 2007.0,
#         "num_of_flights_total": 28988,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 4917,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 301,
#         "num_of_delays_total": 10968,
#         "minutes_delayed_carrier": 131665.0,
#         "minutes_delayed_late_aircraft": 277797,
#         "minutes_delayed_nas": 315372.0,
#         "minutes_delayed_security": 288,
#         "minutes_delayed_weather": 23022,
#         "minutes_delayed_total": 748144
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "March",
#         "year": 2007.0,
#         "num_of_flights_total": 34033,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 2108,
#         "num_of_delays_security": 7,
#         "num_of_delays_weather": 327,
#         "num_of_delays_total": 6341,
#         "minutes_delayed_carrier": 138977.0,
#         "minutes_delayed_late_aircraft": 110820,
#         "minutes_delayed_nas": 83649.0,
#         "minutes_delayed_security": 376,
#         "minutes_delayed_weather": 22799,
#         "minutes_delayed_total": 356621
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "March",
#         "year": 2007.0,
#         "num_of_flights_total": 32447,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 3095.0,
#         "num_of_delays_nas": 5515,
#         "num_of_delays_security": 14,
#         "num_of_delays_weather": 222,
#         "num_of_delays_total": 10591,
#         "minutes_delayed_carrier": 119529.0,
#         "minutes_delayed_late_aircraft": 242557,
#         "minutes_delayed_nas": 456272.0,
#         "minutes_delayed_security": 884,
#         "minutes_delayed_weather": 21102,
#         "minutes_delayed_total": 840344
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": null,
#         "month": "March",
#         "year": 2007.0,
#         "num_of_flights_total": 7824,
#         "num_of_delays_carrier": "537",
#         "num_of_delays_late_aircraft": 544.0,
#         "num_of_delays_nas": 250,
#         "num_of_delays_security": 5,
#         "num_of_delays_weather": 26,
#         "num_of_delays_total": 1365,
#         "minutes_delayed_carrier": 24347.0,
#         "minutes_delayed_late_aircraft": 27938,
#         "minutes_delayed_nas": 8755.0,
#         "minutes_delayed_security": 140,
#         "minutes_delayed_weather": 2295,
#         "minutes_delayed_total": 63475
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "April",
#         "year": null,
#         "num_of_flights_total": 32891,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1826.0,
#         "num_of_delays_nas": 1841,
#         "num_of_delays_security": 7,
#         "num_of_delays_weather": 299,
#         "num_of_delays_total": 5796,
#         "minutes_delayed_carrier": 120428.0,
#         "minutes_delayed_late_aircraft": 104761,
#         "minutes_delayed_nas": 60284.0,
#         "minutes_delayed_security": 329,
#         "minutes_delayed_weather": 19987,
#         "minutes_delayed_total": 305789
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "April",
#         "year": 2007.0,
#         "num_of_flights_total": 31292,
#         "num_of_delays_carrier": "1420",
#         "num_of_delays_late_aircraft": 2877.0,
#         "num_of_delays_nas": 5158,
#         "num_of_delays_security": 12,
#         "num_of_delays_weather": 204,
#         "num_of_delays_total": 9673,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 217560,
#         "minutes_delayed_nas": 392163.0,
#         "minutes_delayed_security": 536,
#         "minutes_delayed_weather": 16656,
#         "minutes_delayed_total": 720092
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "May",
#         "year": 2007.0,
#         "num_of_flights_total": 34178,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1415.0,
#         "num_of_delays_nas": 2328,
#         "num_of_delays_security": 7,
#         "num_of_delays_weather": 193,
#         "num_of_delays_total": 5471,
#         "minutes_delayed_carrier": 95842.0,
#         "minutes_delayed_late_aircraft": 74943,
#         "minutes_delayed_nas": 82974.0,
#         "minutes_delayed_security": 379,
#         "minutes_delayed_weather": 14046,
#         "minutes_delayed_total": 268184
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "June",
#         "year": 2007.0,
#         "num_of_flights_total": 35978,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 4032,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 712,
#         "num_of_delays_total": 10622,
#         "minutes_delayed_carrier": 188228.0,
#         "minutes_delayed_late_aircraft": 211604,
#         "minutes_delayed_nas": 238326.0,
#         "minutes_delayed_security": 622,
#         "minutes_delayed_weather": 65694,
#         "minutes_delayed_total": 704474
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "June",
#         "year": 2007.0,
#         "num_of_flights_total": 31528,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 3240.0,
#         "num_of_delays_nas": 4169,
#         "num_of_delays_security": 17,
#         "num_of_delays_weather": 243,
#         "num_of_delays_total": 9438,
#         "minutes_delayed_carrier": 121622.0,
#         "minutes_delayed_late_aircraft": 238114,
#         "minutes_delayed_nas": 311514.0,
#         "minutes_delayed_security": 567,
#         "minutes_delayed_weather": 21677,
#         "minutes_delayed_total": 693494
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "July",
#         "year": 2007.0,
#         "num_of_flights_total": 36992,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 4321,
#         "num_of_delays_security": 10,
#         "num_of_delays_weather": 812,
#         "num_of_delays_total": 11931,
#         "minutes_delayed_carrier": 210173.0,
#         "minutes_delayed_late_aircraft": 252324,
#         "minutes_delayed_nas": 235974.0,
#         "minutes_delayed_security": 645,
#         "minutes_delayed_weather": 69683,
#         "minutes_delayed_total": 768799
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": null,
#         "month": "July",
#         "year": 2007.0,
#         "num_of_flights_total": 32047,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 3086.0,
#         "num_of_delays_nas": 3441,
#         "num_of_delays_security": 12,
#         "num_of_delays_weather": 238,
#         "num_of_delays_total": 8364,
#         "minutes_delayed_carrier": 109326.0,
#         "minutes_delayed_late_aircraft": 214217,
#         "minutes_delayed_nas": 214364.0,
#         "minutes_delayed_security": 604,
#         "minutes_delayed_weather": 20933,
#         "minutes_delayed_total": 559444
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "August",
#         "year": 2007.0,
#         "num_of_flights_total": 37284,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 4041,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 592,
#         "num_of_delays_total": 10970,
#         "minutes_delayed_carrier": 220796.0,
#         "minutes_delayed_late_aircraft": 211011,
#         "minutes_delayed_nas": 215831.0,
#         "minutes_delayed_security": 298,
#         "minutes_delayed_weather": 53031,
#         "minutes_delayed_total": 700967
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "August",
#         "year": 2007.0,
#         "num_of_flights_total": 32483,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 3852.0,
#         "num_of_delays_nas": 4302,
#         "num_of_delays_security": 14,
#         "num_of_delays_weather": 210,
#         "num_of_delays_total": 10068,
#         "minutes_delayed_carrier": 117760.0,
#         "minutes_delayed_late_aircraft": 277889,
#         "minutes_delayed_nas": 277969.0,
#         "minutes_delayed_security": 499,
#         "minutes_delayed_weather": 18391,
#         "minutes_delayed_total": 692508
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "September",
#         "year": null,
#         "num_of_flights_total": 34271,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 1616.0,
#         "num_of_delays_nas": 2584,
#         "num_of_delays_security": 8,
#         "num_of_delays_weather": 299,
#         "num_of_delays_total": 6862,
#         "minutes_delayed_carrier": 182309.0,
#         "minutes_delayed_late_aircraft": 98189,
#         "minutes_delayed_nas": 123976.0,
#         "minutes_delayed_security": 340,
#         "minutes_delayed_weather": 26559,
#         "minutes_delayed_total": 431373
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": null,
#         "month": null,
#         "year": 2007.0,
#         "num_of_flights_total": 12015,
#         "num_of_delays_carrier": "670",
#         "num_of_delays_late_aircraft": 671.0,
#         "num_of_delays_nas": 324,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 29,
#         "num_of_delays_total": 1704,
#         "minutes_delayed_carrier": 28345.0,
#         "minutes_delayed_late_aircraft": 31081,
#         "minutes_delayed_nas": 10544.0,
#         "minutes_delayed_security": 272,
#         "minutes_delayed_weather": 2335,
#         "minutes_delayed_total": 72577
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
# ...
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 53,
#         "num_of_delays_total": 3072,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 77283,
#         "minutes_delayed_nas": 34012.0,
#         "minutes_delayed_security": 107,
#         "minutes_delayed_weather": 4890,
#         "minutes_delayed_total": 165260
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": null,
#         "month": "May",
#         "year": 2014.0,
#         "num_of_flights_total": 31799,
#         "num_of_delays_carrier": "1323",
#         "num_of_delays_late_aircraft": 2052.0,
#         "num_of_delays_nas": 1624,
#         "num_of_delays_security": 7,
#         "num_of_delays_weather": 130,
#         "num_of_delays_total": 5135,
#         "minutes_delayed_carrier": 111962.0,
#         "minutes_delayed_late_aircraft": 124918,
#         "minutes_delayed_nas": 62921.0,
#         "minutes_delayed_security": 378,
#         "minutes_delayed_weather": 9651,
#         "minutes_delayed_total": 309830
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "June",
#         "year": 2014.0,
#         "num_of_flights_total": 6742,
#         "num_of_delays_carrier": "566",
#         "num_of_delays_late_aircraft": 819.0,
#         "num_of_delays_nas": 348,
#         "num_of_delays_security": 5,
#         "num_of_delays_weather": 40,
#         "num_of_delays_total": 1779,
#         "minutes_delayed_carrier": 30506.0,
#         "minutes_delayed_late_aircraft": 45125,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 179,
#         "minutes_delayed_weather": 3574,
#         "minutes_delayed_total": 92357
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": null,
#         "year": 2014.0,
#         "num_of_flights_total": 14372,
#         "num_of_delays_carrier": "966",
#         "num_of_delays_late_aircraft": 1394.0,
#         "num_of_delays_nas": 2051,
#         "num_of_delays_security": 4,
#         "num_of_delays_weather": 146,
#         "num_of_delays_total": 4560,
#         "minutes_delayed_carrier": 58157.0,
#         "minutes_delayed_late_aircraft": 94933,
#         "minutes_delayed_nas": 99550.0,
#         "minutes_delayed_security": 220,
#         "minutes_delayed_weather": 10474,
#         "minutes_delayed_total": 263334
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "August",
#         "year": null,
#         "num_of_flights_total": 31608,
#         "num_of_delays_carrier": "1365",
#         "num_of_delays_late_aircraft": 1769.0,
#         "num_of_delays_nas": 1668,
#         "num_of_delays_security": 1,
#         "num_of_delays_weather": 141,
#         "num_of_delays_total": 4944,
#         "minutes_delayed_carrier": 121594.0,
#         "minutes_delayed_late_aircraft": 122937,
#         "minutes_delayed_nas": 95866.0,
#         "minutes_delayed_security": 68,
#         "minutes_delayed_weather": 12785,
#         "minutes_delayed_total": 353250
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "August",
#         "year": 2014.0,
#         "num_of_flights_total": 5060,
#         "num_of_delays_carrier": "249",
#         "num_of_delays_late_aircraft": 426.0,
#         "num_of_delays_nas": 293,
#         "num_of_delays_security": 2,
#         "num_of_delays_weather": 40,
#         "num_of_delays_total": 1010,
#         "minutes_delayed_carrier": 15180.0,
#         "minutes_delayed_late_aircraft": 30880,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 45,
#         "minutes_delayed_weather": 3095,
#         "minutes_delayed_total": 62655
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": null,
#         "month": "September",
#         "year": 2014.0,
#         "num_of_flights_total": 24905,
#         "num_of_delays_carrier": "811",
#         "num_of_delays_late_aircraft": 1829.0,
#         "num_of_delays_nas": 2960,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 115,
#         "num_of_delays_total": 5724,
#         "minutes_delayed_carrier": 60377.0,
#         "minutes_delayed_late_aircraft": 118588,
#         "minutes_delayed_nas": 198063.0,
#         "minutes_delayed_security": 350,
#         "minutes_delayed_weather": 13169,
#         "minutes_delayed_total": 390547
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "September",
#         "year": 2014.0,
#         "num_of_flights_total": 13871,
#         "num_of_delays_carrier": "601",
#         "num_of_delays_late_aircraft": 939.0,
#         "num_of_delays_nas": 1811,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 69,
#         "num_of_delays_total": 3429,
#         "minutes_delayed_carrier": 33162.0,
#         "minutes_delayed_late_aircraft": 61126,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 516,
#         "minutes_delayed_weather": 4120,
#         "minutes_delayed_total": 192709
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": null,
#         "month": "November",
#         "year": 2014.0,
#         "num_of_flights_total": 29296,
#         "num_of_delays_carrier": "954",
#         "num_of_delays_late_aircraft": 1227.0,
#         "num_of_delays_nas": 1175,
#         "num_of_delays_security": 5,
#         "num_of_delays_weather": 61,
#         "num_of_delays_total": 3420,
#         "minutes_delayed_carrier": 74609.0,
#         "minutes_delayed_late_aircraft": 68028,
#         "minutes_delayed_nas": 35915.0,
#         "minutes_delayed_security": 214,
#         "minutes_delayed_weather": 5462,
#         "minutes_delayed_total": 184228
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": null,
#         "month": "November",
#         "year": 2014.0,
#         "num_of_flights_total": 8457,
#         "num_of_delays_carrier": "345",
#         "num_of_delays_late_aircraft": 452.0,
#         "num_of_delays_nas": 333,
#         "num_of_delays_security": 1,
#         "num_of_delays_weather": 17,
#         "num_of_delays_total": 1152,
#         "minutes_delayed_carrier": 27394.0,
#         "minutes_delayed_late_aircraft": 25546,
#         "minutes_delayed_nas": 10417.0,
#         "minutes_delayed_security": 49,
#         "minutes_delayed_weather": 827,
#         "minutes_delayed_total": 64233
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "January",
#         "year": 2015.0,
#         "num_of_flights_total": 12883,
#         "num_of_delays_carrier": "643",
#         "num_of_delays_late_aircraft": 986.0,
#         "num_of_delays_nas": 1116,
#         "num_of_delays_security": 1,
#         "num_of_delays_weather": 99,
#         "num_of_delays_total": 2850,
#         "minutes_delayed_carrier": 38996.0,
#         "minutes_delayed_late_aircraft": 68063,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 107,
#         "minutes_delayed_weather": 6856,
#         "minutes_delayed_total": 176783
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "January",
#         "year": 2015.0,
#         "num_of_flights_total": 8626,
#         "num_of_delays_carrier": "376",
#         "num_of_delays_late_aircraft": 479.0,
#         "num_of_delays_nas": 289,
#         "num_of_delays_security": 2,
#         "num_of_delays_weather": 45,
#         "num_of_delays_total": 1191,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 29169,
#         "minutes_delayed_nas": 9708.0,
#         "minutes_delayed_security": 60,
#         "minutes_delayed_weather": 3734,
#         "minutes_delayed_total": 67026
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": null,
#         "month": "March",
#         "year": 2015.0,
#         "num_of_flights_total": 13431,
#         "num_of_delays_carrier": "653",
#         "num_of_delays_late_aircraft": 825.0,
#         "num_of_delays_nas": 864,
#         "num_of_delays_security": 0,
#         "num_of_delays_weather": 82,
#         "num_of_delays_total": 2421,
#         "minutes_delayed_carrier": 41702.0,
#         "minutes_delayed_late_aircraft": 58215,
#         "minutes_delayed_nas": 40798.0,
#         "minutes_delayed_security": 17,
#         "minutes_delayed_weather": 5231,
#         "minutes_delayed_total": 145963
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "June",
#         "year": null,
#         "num_of_flights_total": 32739,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 2300.0,
#         "num_of_delays_nas": 1803,
#         "num_of_delays_security": 8,
#         "num_of_delays_weather": 172,
#         "num_of_delays_total": 6031,
#         "minutes_delayed_carrier": 148949.0,
#         "minutes_delayed_late_aircraft": 164521,
#         "minutes_delayed_nas": 98579.0,
#         "minutes_delayed_security": 516,
#         "minutes_delayed_weather": 17265,
#         "minutes_delayed_total": 429830
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": null,
#         "month": "June",
#         "year": 2015.0,
#         "num_of_flights_total": 27590,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 2551.0,
#         "num_of_delays_nas": 3544,
#         "num_of_delays_security": 8,
#         "num_of_delays_weather": 250,
#         "num_of_delays_total": 7889,
#         "minutes_delayed_carrier": 121806.0,
#         "minutes_delayed_late_aircraft": 197034,
#         "minutes_delayed_nas": 235468.0,
#         "minutes_delayed_security": 341,
#         "minutes_delayed_weather": 26927,
#         "minutes_delayed_total": 581576
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "August",
#         "year": 2015.0,
#         "num_of_flights_total": 3228,
#         "num_of_delays_carrier": "218",
#         "num_of_delays_late_aircraft": 201.0,
#         "num_of_delays_nas": 116,
#         "num_of_delays_security": 2,
#         "num_of_delays_weather": 40,
#         "num_of_delays_total": 576,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 14135,
#         "minutes_delayed_nas": 8155.0,
#         "minutes_delayed_security": 88,
#         "minutes_delayed_weather": 2729,
#         "minutes_delayed_total": 36951
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "August",
#         "year": 2015.0,
#         "num_of_flights_total": 6876,
#         "num_of_delays_carrier": "443",
#         "num_of_delays_late_aircraft": 510.0,
#         "num_of_delays_nas": 228,
#         "num_of_delays_security": 1,
#         "num_of_delays_weather": 32,
#         "num_of_delays_total": 1212,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 28069,
#         "minutes_delayed_nas": 8680.0,
#         "minutes_delayed_security": 45,
#         "minutes_delayed_weather": 2134,
#         "minutes_delayed_total": 60636
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "August",
#         "year": 2015.0,
#         "num_of_flights_total": 9502,
#         "num_of_delays_carrier": "384",
#         "num_of_delays_late_aircraft": 528.0,
#         "num_of_delays_nas": 195,
#         "num_of_delays_security": 2,
#         "num_of_delays_weather": 47,
#         "num_of_delays_total": 1157,
#         "minutes_delayed_carrier": 24081.0,
#         "minutes_delayed_late_aircraft": 28489,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 116,
#         "minutes_delayed_weather": 3113,
#         "minutes_delayed_total": 63116
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "October",
#         "year": 2015.0,
#         "num_of_flights_total": 8764,
#         "num_of_delays_carrier": "234",
#         "num_of_delays_late_aircraft": 257.0,
#         "num_of_delays_nas": 150,
#         "num_of_delays_security": 1,
#         "num_of_delays_weather": 10,
#         "num_of_delays_total": 652,
#         "minutes_delayed_carrier": 15522.0,
#         "minutes_delayed_late_aircraft": 14155,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 40,
#         "minutes_delayed_weather": 1765,
#         "minutes_delayed_total": 35799
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": null,
#         "month": "November",
#         "year": 2015.0,
#         "num_of_flights_total": 17120,
#         "num_of_delays_carrier": "751",
#         "num_of_delays_late_aircraft": 1031.0,
#         "num_of_delays_nas": 1197,
#         "num_of_delays_security": 1,
#         "num_of_delays_weather": 93,
#         "num_of_delays_total": 3076,
#         "minutes_delayed_carrier": 54704.0,
#         "minutes_delayed_late_aircraft": 69918,
#         "minutes_delayed_nas": 50919.0,
#         "minutes_delayed_security": 63,
#         "minutes_delayed_weather": 9509,
#         "minutes_delayed_total": 185113
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "November",
#         "year": 2015.0,
#         "num_of_flights_total": 5965,
#         "num_of_delays_carrier": "307",
#         "num_of_delays_late_aircraft": 364.0,
#         "num_of_delays_nas": 284,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 36,
#         "num_of_delays_total": 997,
#         "minutes_delayed_carrier": 15502.0,
#         "minutes_delayed_late_aircraft": 18896,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 253,
#         "minutes_delayed_weather": 3615,
#         "minutes_delayed_total": 50942
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "December",
#         "year": 2015.0,
#         "num_of_flights_total": 31030,
#         "num_of_delays_carrier": null,
#         "num_of_delays_late_aircraft": 2176.0,
#         "num_of_delays_nas": 1616,
#         "num_of_delays_security": 10,
#         "num_of_delays_weather": 147,
#         "num_of_delays_total": 5474,
#         "minutes_delayed_carrier": 148033.0,
#         "minutes_delayed_late_aircraft": 173784,
#         "minutes_delayed_nas": 93850.0,
#         "minutes_delayed_security": 313,
#         "minutes_delayed_weather": 19532,
#         "minutes_delayed_total": 435512
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "December",
#         "year": 2015.0,
#         "num_of_flights_total": 2799,
#         "num_of_delays_carrier": "182",
#         "num_of_delays_late_aircraft": 183.0,
#         "num_of_delays_nas": 61,
#         "num_of_delays_security": 0,
#         "num_of_delays_weather": 17,
#         "num_of_delays_total": 443,
#         "minutes_delayed_carrier": null,
#         "minutes_delayed_late_aircraft": 15438,
#         "minutes_delayed_nas": 2826.0,
#         "minutes_delayed_security": 0,
#         "minutes_delayed_weather": 1825,
#         "minutes_delayed_total": 31164
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": null,
#         "year": 2015.0,
#         "num_of_flights_total": 6231,
#         "num_of_delays_carrier": "480",
#         "num_of_delays_late_aircraft": 606.0,
#         "num_of_delays_nas": 256,
#         "num_of_delays_security": 5,
#         "num_of_delays_weather": 37,
#         "num_of_delays_total": 1383,
#         "minutes_delayed_carrier": 25402.0,
#         "minutes_delayed_late_aircraft": 35796,
#         "minutes_delayed_nas": 9038.0,
#         "minutes_delayed_security": 161,
#         "minutes_delayed_weather": 2742,
#         "minutes_delayed_total": 73139
#     }
# ]
